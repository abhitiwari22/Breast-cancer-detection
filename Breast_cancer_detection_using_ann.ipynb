# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/breast cancer/20210926_DSC 7452 _Batch97_Modeule End Mentosrship_Case Study/breast_cancer_dataframe.csv")
df.head()
# Out:
#    Unnamed: 0  mean radius  ...  worst fractal dimension  target
# 0           0        17.99  ...                  0.11890     0.0
# 1           1        20.57  ...                  0.08902     0.0
# 2           2        19.69  ...                  0.08758     0.0
# 3           3        11.42  ...                  0.17300     0.0
# 4           4        20.29  ...                  0.07678     0.0
#
# [5 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
df.shape
# Out:
# (569, 32)

# %%
df.target.value_counts()
# Out:
# 1.0    357
# 0.0    212
# Name: target, dtype: int64

# %%
df.drop(["Unnamed: 0"],axis=1)
# Out:
#      mean radius  mean texture  ...  worst fractal dimension  target
# 0          17.99         10.38  ...                  0.11890     0.0
# 1          20.57         17.77  ...                  0.08902     0.0
# 2          19.69         21.25  ...                  0.08758     0.0
# 3          11.42         20.38  ...                  0.17300     0.0
# 4          20.29         14.34  ...                  0.07678     0.0
# ..           ...           ...  ...                      ...     ...
# 564        21.56         22.39  ...                  0.07115     0.0
# 565        20.13         28.25  ...                  0.06637     0.0
# 566        16.60         28.08  ...                  0.07820     0.0
# 567        20.60         29.33  ...                  0.12400     0.0
# 568         7.76         24.54  ...                  0.07039     1.0
#
# [569 rows x 31 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                 float64
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# worst concave points       float64
# worst symmetry             float64
# worst fractal dimension    float64
# target                     float64
# dtype: object

# %%
#visualizing the target feature
sns.countplot(df['target'],label = 'count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#independent and Dependent features
X =df.drop(['target'], axis = 1)
y =df['target']

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Initialising the ANN
classifier = Sequential()
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 31))
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size=100, epochs=150)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 3s 6ms/step - loss: 0.6929 - accuracy: 0.5704
# Epoch 2/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.6256
# Epoch 3/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6917 - accuracy: 0.6256
# Epoch 4/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6910 - accuracy: 0.6256
# Epoch 5/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6903 - accuracy: 0.6256
# Epoch 6/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6894 - accuracy: 0.6256
# Epoch 7/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6883 - accuracy: 0.6256
# Epoch 8/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6868 - accuracy: 0.6256
# Epoch 9/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6849 - accuracy: 0.6256
# Epoch 10/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6827 - accuracy: 0.6256
# Epoch 11/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6797 - accuracy: 0.6281
# Epoch 12/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6758 - accuracy: 0.6281
# Epoch 13/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6710 - accuracy: 0.6583
# Epoch 14/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6649 - accuracy: 0.7161
# Epoch 15/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6573 - accuracy: 0.7940
# Epoch 16/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6481 - accuracy: 0.8618
# Epoch 17/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6366 - accuracy: 0.9045
# Epoch 18/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6227 - accuracy: 0.9322
# Epoch 19/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6056 - accuracy: 0.9447
# Epoch 20/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5860 - accuracy: 0.9573
# Epoch 21/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5637 - accuracy: 0.9623
# Epoch 22/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5375 - accuracy: 0.9698
# Epoch 23/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5086 - accuracy: 0.9673
# Epoch 24/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4776 - accuracy: 0.9673
# Epoch 25/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4442 - accuracy: 0.9698
# Epoch 26/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4091 - accuracy: 0.9698
# Epoch 27/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3744 - accuracy: 0.9698
# Epoch 28/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3400 - accuracy: 0.9698
# Epoch 29/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3079 - accuracy: 0.9698
# Epoch 30/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2781 - accuracy: 0.9698
# Epoch 31/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2508 - accuracy: 0.9724
# Epoch 32/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2267 - accuracy: 0.9724
# Epoch 33/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2062 - accuracy: 0.9724
# Epoch 34/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1881 - accuracy: 0.9724
# Epoch 35/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1720 - accuracy: 0.9749
# Epoch 36/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1585 - accuracy: 0.9749
# Epoch 37/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1466 - accuracy: 0.9774
# Epoch 38/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1366 - accuracy: 0.9774
# Epoch 39/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1280 - accuracy: 0.9774
# Epoch 40/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1210 - accuracy: 0.9774
# Epoch 41/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1149 - accuracy: 0.9774
# Epoch 42/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1092 - accuracy: 0.9799
# Epoch 43/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1045 - accuracy: 0.9824
# Epoch 44/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1005 - accuracy: 0.9824
# Epoch 45/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0967 - accuracy: 0.9824
# Epoch 46/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0934 - accuracy: 0.9824
# Epoch 47/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0908 - accuracy: 0.9824
# Epoch 48/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0883 - accuracy: 0.9824
# Epoch 49/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0859 - accuracy: 0.9824
# Epoch 50/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0839 - accuracy: 0.9824
# Epoch 51/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0819 - accuracy: 0.9824
# Epoch 52/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0802 - accuracy: 0.9824
# Epoch 53/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9824
# Epoch 54/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0771 - accuracy: 0.9824
# Epoch 55/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0758 - accuracy: 0.9824
# Epoch 56/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.9824
# Epoch 57/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0733 - accuracy: 0.9824
# Epoch 58/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0722 - accuracy: 0.9824
# Epoch 59/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0711 - accuracy: 0.9824
# Epoch 60/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0701 - accuracy: 0.9824
# Epoch 61/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0692 - accuracy: 0.9824
# Epoch 62/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0683 - accuracy: 0.9824
# Epoch 63/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0675 - accuracy: 0.9824
# Epoch 64/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0666 - accuracy: 0.9824
# Epoch 65/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0658 - accuracy: 0.9824
# Epoch 66/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0651 - accuracy: 0.9824
# Epoch 67/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0643 - accuracy: 0.9824
# Epoch 68/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0636 - accuracy: 0.9824
# Epoch 69/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0628 - accuracy: 0.9824
# Epoch 70/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0621 - accuracy: 0.9824
# Epoch 71/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0613 - accuracy: 0.9824
# Epoch 72/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0607 - accuracy: 0.9824
# Epoch 73/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0598 - accuracy: 0.9824
# Epoch 74/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0590 - accuracy: 0.9824
# Epoch 75/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0583 - accuracy: 0.9849
# Epoch 76/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 0.9849
# Epoch 77/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0569 - accuracy: 0.9849
# Epoch 78/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 0.9874
# Epoch 79/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0555 - accuracy: 0.9874
# Epoch 80/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0549 - accuracy: 0.9874
# Epoch 81/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 0.9874
# Epoch 82/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0537 - accuracy: 0.9874
# Epoch 83/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0529 - accuracy: 0.9874
# Epoch 84/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0523 - accuracy: 0.9874
# Epoch 85/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0518 - accuracy: 0.9874
# Epoch 86/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0511 - accuracy: 0.9899
# Epoch 87/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0503 - accuracy: 0.9899
# Epoch 88/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0497 - accuracy: 0.9899
# Epoch 89/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9899
# Epoch 90/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9899
# Epoch 91/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9899
# Epoch 92/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0471 - accuracy: 0.9899
# Epoch 93/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0466 - accuracy: 0.9899
# Epoch 94/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0462 - accuracy: 0.9899
# Epoch 95/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0458 - accuracy: 0.9899
# Epoch 96/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0455 - accuracy: 0.9899
# Epoch 97/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0450 - accuracy: 0.9899
# Epoch 98/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0446 - accuracy: 0.9899
# Epoch 99/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0442 - accuracy: 0.9899
# Epoch 100/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0438 - accuracy: 0.9899
# Epoch 101/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0436 - accuracy: 0.9899
# Epoch 102/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0432 - accuracy: 0.9899
# Epoch 103/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0429 - accuracy: 0.9899
# Epoch 104/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0426 - accuracy: 0.9899
# Epoch 105/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0423 - accuracy: 0.9899
# Epoch 106/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0421 - accuracy: 0.9899
# Epoch 107/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0417 - accuracy: 0.9925
# Epoch 108/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0415 - accuracy: 0.9925
# Epoch 109/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0412 - accuracy: 0.9925
# Epoch 110/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0409 - accuracy: 0.9925
# Epoch 111/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0407 - accuracy: 0.9925
# Epoch 112/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0404 - accuracy: 0.9925
# Epoch 113/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 0.9925
# Epoch 114/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0400 - accuracy: 0.9925
# Epoch 115/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0397 - accuracy: 0.9925
# Epoch 116/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 0.9925
# Epoch 117/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0390 - accuracy: 0.9925
# Epoch 118/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.9925
# Epoch 119/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0384 - accuracy: 0.9925
# Epoch 120/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 0.9925
# Epoch 121/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0377 - accuracy: 0.9925
# Epoch 122/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9925
# Epoch 123/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0372 - accuracy: 0.9925
# Epoch 124/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 0.9925
# Epoch 125/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0367 - accuracy: 0.9925
# Epoch 126/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0364 - accuracy: 0.9925
# Epoch 127/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0362 - accuracy: 0.9925
# Epoch 128/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0359 - accuracy: 0.9950
# Epoch 129/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0357 - accuracy: 0.9950
# Epoch 130/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0354 - accuracy: 0.9950
# Epoch 131/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0352 - accuracy: 0.9950
# Epoch 132/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0349 - accuracy: 0.9950
# Epoch 133/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0347 - accuracy: 0.9950
# Epoch 134/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0345 - accuracy: 0.9950
# Epoch 135/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0343 - accuracy: 0.9950
# Epoch 136/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0340 - accuracy: 0.9950
# Epoch 137/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0337 - accuracy: 0.9950
# Epoch 138/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0336 - accuracy: 0.9950
# Epoch 139/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 0.9950
# Epoch 140/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0331 - accuracy: 0.9950
# Epoch 141/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0328 - accuracy: 0.9950
# Epoch 142/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0327 - accuracy: 0.9950
# Epoch 143/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0324 - accuracy: 0.9950
# Epoch 144/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0322 - accuracy: 0.9950
# Epoch 145/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0320 - accuracy: 0.9950
# Epoch 146/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0318 - accuracy: 0.9950
# Epoch 147/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 0.9950
# Epoch 148/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0313 - accuracy: 0.9950
# Epoch 149/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 0.9950
# Epoch 150/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0309 - accuracy: 0.9950

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")
# Out:
# [[ 60   3]
#  [  2 106]]
# Accuracy: 97.07602339181285%
